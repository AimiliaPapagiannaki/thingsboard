# %%
import json

# %%
physical_meters = [
    '102.402.002072',
    '102.402.002036',
    '102.402.002037',
    '102.402.002038',
    '102.402.001582',
    '102.402.001600',
    '102.402.001595',
    '102.402.002018',
    '102.402.002021',
    '102.402.002016',
    '102.301.001193',
    '102.402.002020',
    '102.402.002033',
    '102.402.002035',
    '102.402.001601',
    '102.301.001273',
    '102.301.001074',
    '102.402.001514',
    '102.402.001571',
    '102.402.002022',
    '102.402.002028',
    '102.402.002021',
    '102.402.002014',
    '102.402.001589',
    '102.402.002026',
    '102.301.001197',
    '102.402.002025',
    '102.402.002024',
    '102.402.002019',
    '102.402.001186',
    '102.402.001187',
    '102.402.001413',
    '102.402.001185'
]

virtualMeters = {
    'Κλιματισμός ΚΕΤ':[
        '102.402.001582',
        '102.402.001600',
        '102.402.001595'
    ],
    'Κλιματισμός Αμφιθέατρο':[
        '102.301.001193',
        '102.402.001601'
    ],
    'Κλιματισμός':[
        'Κλιματισμός ΚΕΤ',
        'Κλιματισμός Αμφιθέατρο',
        '102.301.001074',
        '102.402.001571',
        '102.402.002021',
        '102.402.001589'
    ],
    'Ψύκτες':[
        '102.402.001186',
        '102.402.001187',
        '102.402.001413',
        '102.402.001185'
    ],
    'Virtual Meter 36 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΚΕΤ':[
        'Κλιματισμός ΚΕΤ',
        'Κλιματισμός',
        'Ψύκτες'
    ],
    'Virtual Meter 37 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΜΦΙΘΕΑΤΡΟ':[
        'Κλιματισμός Αμφιθέατρο',
        'Κλιματισμός',
        'Ψύκτες'
    ],
    'Virtual Meter 38 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΙΘ. ΔΙΑΛΕΞΕΩΝ  Α\' ΟΡΟΦΟΣ':[
        '102.402.001571',
        'Κλιματισμός',
        'Ψύκτες'
    ],
    'Virtual Meter 39 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ U - TECH LAB':[
        '102.402.002021',
        'Κλιματισμός',
        'Ψύκτες'
    ],
    'Virtual Meter 40 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΒΙΒΛΙΟΘΗΚΗΣ':[
        '102.402.001589',
        'Κλιματισμός',
        'Ψύκτες'
    ],
    'Φωτισμός':[
        '102.402.002036',
        '102.402.002037',
        '102.402.002038',
        '102.402.002018',
        '102.402.002020',
        '102.402.002033',
        '102.402.002035',
        '102.402.001514',
        '102.402.002022',
        '102.402.002028',
        '102.402.002014',
        '102.402.002024',
        '102.402.002019',
    ],
    'Η/Μ Εξοπλισμός':[
        '102.402.002021',
        '102.402.002016',
        '102.402.002026',
        '102.301.001197',
        '102.402.002025'
    ],
    'Κέντρο Ερευνας & Τεχνολογίας (ΚΕΤ)':[
        '102.402.002036',
        '102.402.002037',
        '102.402.002038',
        '102.402.001582',
        '102.402.001600',
        '102.402.001595',
        'Virtual Meter 36 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΚΕΤ'
    ],
    'Αμφιθέατρο':[
        '102.402.002018',
        '102.402.002021',
        '102.402.002016',
        '102.301.001193',
        '102.402.002020',
        '102.402.002033',
        '102.402.002035',
        '102.402.001601',
        'Virtual Meter 37 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΜΦΙΘΕΑΤΡΟ'
    ],
    'Πλανητάριο':[
        '102.301.001273',
        '102.301.001074',
        '102.402.001413'
    ],
    'Αίθουσα Διαλέξεων':[
        '102.402.001571',
        '102.402.002022',
        'Virtual Meter 38 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΙΘ. ΔΙΑΛΕΞΕΩΝ  Α\' ΟΡΟΦΟΣ'
    ],
    'U - TECH LAB':[
        '102.402.002028',
        '102.402.002021',
        'Virtual Meter 39 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ U - TECH LAB'
    ],
    'Βιβλιοθήκη':[
        '102.402.002014',
        '102.402.001589',
        'Virtual Meter 40 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΒΙΒΛΙΟΘΗΚΗΣ' 
    ],
    'Υποσύνολο':
        ['102.402.002036',
    '102.402.002037',
    '102.402.002038',
    '102.402.001582',
    '102.402.001600',
    '102.402.001595',
    '102.402.002018',
    '102.402.002021',
    '102.402.002016',
    '102.301.001193',
    '102.402.002020',
    '102.402.002033',
    '102.402.002035',
    '102.402.001601',
    '102.301.001273',
    '102.301.001074',
    '102.402.001413',
    '102.402.001514',
    '102.402.001571',
    '102.402.002022',
    '102.402.002028',
    '102.402.002021',
    '102.402.002014',
    '102.402.001589',
    '102.402.002026',
    '102.301.001197',
    '102.402.002025',
    '102.402.002024',
    '102.402.002019',
    'Virtual Meter 36 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΚΕΤ',
    'Virtual Meter 37 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΜΦΙΘΕΑΤΡΟ',
    'Virtual Meter 38 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΙΘ. ΔΙΑΛΕΞΕΩΝ  Α\' ΟΡΟΦΟΣ',
    'Virtual Meter 39 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ U - TECH LAB',
    'Virtual Meter 40 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΒΙΒΛΙΟΘΗΚΗΣ' 
    ],
    # [
    #     'Kέντρο Ερευνας & Τεχνολογίας (ΚΕΤ)',
    #     'Αμφιθέατρο',
    #     'Πλανητάριο',
    #     'Αίθουσα Διαλέξεων',
    #     'U - TECH LAB',
    #     'Βιβλιοθήκη',
    #     '102.402.001514',
    #     '102.402.002026',
    #     '102.301.001197',
    #     '102.402.002025',
    #     '102.402.002024',
    #     '102.402.002019'
    # ],
    'VIRTUAL METER 41 - ΛΟΙΠΑ ΦΟΡΤΙΑ ΕΓΚΑΤΑΣΤΑΣΗΣ':[
        '102.402.002072',
        'Υποσύνολο'
    ]
}
subtract_meters=['VIRTUAL METER 41 - ΛΟΙΠΑ ΦΟΡΤΙΑ ΕΓΚΑΤΑΣΤΑΣΗΣ']
complex_calc_meters = ['Virtual Meter 36 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΚΕΤ','Virtual Meter 37 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΜΦΙΘΕΑΤΡΟ','Virtual Meter 38 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΑΙΘ. ΔΙΑΛΕΞΕΩΝ  Α\' ΟΡΟΦΟΣ','Virtual Meter 39 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ U - TECH LAB','Virtual Meter 40 - ΚΑΤΑΝΑΛΩΣΗ ΨΥΚΤΩΝ ΒΙΒΛΙΟΘΗΚΗΣ']
unwriteable = ['Κλιματισμός ΚΕΤ','Κλιματισμός Αμφιθέατρο','Υποσύνολο']
assetdevs = ['Kέντρο Ερευνας & Τεχνολογίας (ΚΕΤ)','Αμφιθέατρο','Πλανητάριο','Αίθουσα Διαλέξεων','U - TECH LAB','Βιβλιοθήκη']

# %%
data = {
    "physical_meters": physical_meters,
    "virtualMeters": virtualMeters,
    "subtract_meters":subtract_meters,
    "complex_calc_meters":complex_calc_meters,
    "unwriteable":unwriteable,
    "assetdevs":assetdevs
}

# Step 3: Save data to a JSON file
filename = 'meters_info.json'

with open(filename, 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

# %%
import requests
address = 'https://mi6.meazon.com'
r = requests.post(address + "/api/auth/login",
                      json={'username': 'meazonpro@meazon.com', 'password': 'meazonpro1'}).json()
    # acc_token is the token to be used in the next request
acc_token = 'Bearer' + ' ' + r['token']

# %%
entity = 'device'
device = '102.402.001188'
response = requests.get(
        url=f"{address}/api/tenant/{entity}s",
        params={entity+"Name": device},
        headers={
            'Content-Type': 'application/json',
            'Accept': '*/*',
            'X-Authorization': acc_token
        }
    )

devid = response.json()
print(devid)
# Out:
# {'status': 404, 'message': "Requested item wasn't found!", 'errorCode': 32, 'timestamp': '2024-06-25T08:29:27.541+00:00', 'subscriptionErrorCode': None, 'subscriptionEntry': None, 'subscriptionValue': None}

# %%
descriptors = 'cnrgA,cnrgB,cnrgC'
st = '1717102800000' 
en = '1717189200000'
ADDRESS = 'https://mi6.meazon.com'
response = requests.get(
                url=f"{ADDRESS}/api/plugins/telemetry/DEVICE/{devid}/values/timeseries",
                params={
                    "keys": descriptors,
                    "startTs": st,
                    "endTs": en,
                    "agg": "NONE",
                    "limit": 1000000
                },
                headers={
                    'Content-Type': 'application/json',
                    'Accept': '*/*',
                    'X-Authorization': acc_token
                }
            )

response.json()
# Out:
# {'cnrgA': [{'ts': 1717188927000, 'value': '4487771'},
#   {'ts': 1717188627000, 'value': '4487601'},
#   {'ts': 1717188327000, 'value': '4487431'},
#   {'ts': 1717188027000, 'value': '4487261'},
#   {'ts': 1717187727000, 'value': '4487091'},
#   {'ts': 1717187427000, 'value': '4486921'},
#   {'ts': 1717187127000, 'value': '4486750'},
#   {'ts': 1717186827000, 'value': '4486579'},
#   {'ts': 1717186527000, 'value': '4486407'},
#   {'ts': 1717186227000, 'value': '4486237'},
#   {'ts': 1717185927000, 'value': '4486067'},
#   {'ts': 1717185627000, 'value': '4485896'},
#   {'ts': 1717185327000, 'value': '4485725'},
#   {'ts': 1717185027000, 'value': '4485555'},
#   {'ts': 1717184727000, 'value': '4485384'},
#   {'ts': 1717184427000, 'value': '4485214'},
#   {'ts': 1717184127000, 'value': '4485043'},
#   {'ts': 1717183827000, 'value': '4484873'},
#   {'ts': 1717183527000, 'value': '4484702'},
#   {'ts': 1717183227000, 'value': '4484531'},
#   {'ts': 1717182927000, 'value': '4484359'},
# ...

# %%
import requests
address = 'https://mi6.meazon.com'
r = requests.post(address + "/api/auth/login",
                      json={'username': 'meazonpro@meazon.com', 'password': 'meazonpro1'}).json()
# acc_token is the token to be used in the next request
acc_token = 'Bearer' + ' ' + r['token']
acc_token
# Out:
# 'Bearer eyJhbGciOiJIUzUxMiJ9.....PQE7h7vdQnDcrzBHX4Dlq3lR5Q5AhEOEHUgwEUNSIEG6T-KjPVBjDECOHFC43nE0hsipRJIz0iTk1mp_2d574Q'

# %%
devid = 'd6496ae0-7d77-11ee-b97f-098b03a95eb1'
start_time = '1709296442000'
end_time = '1711974842000'
descriptors = 'pwrA'
# url = f"{address}/api/plugins/telemetry/DEVICE/{devid}/values/timeseries"

response = requests.get(
    url="https://mi6.meazon.com/api/plugins/telemetry/DEVICE/d6496ae0-7d77-11ee-b97f-098b03a95eb1/values/timeseries",
    params={
        "keys": descriptors,
        "startTs": start_time,
        "endTs": end_time,
        "agg": "NONE",
        "limit": 1000000
    },
    headers={
        'Content-Type': 'application/json',
        'Accept': '*/*',
        'X-Authorization': acc_token
    }
)
response.content
# Out:
# b"Device with requested id wasn't found!"
